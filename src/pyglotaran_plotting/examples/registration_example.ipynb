# %%
from glotaran.plugin_system.megacomplex_registration import known_megacomplex_names
from glotaran.plugin_system.megacomplex_registration import register_megacomplex
import delayed_damped_oscillation_megacomplex
register_megacomplex(megacomplex_type='delayed-damped-oscillation',
                     megacomplex=delayed_damped_oscillation_megacomplex.DelayDampedOscillationMegacomplex)
